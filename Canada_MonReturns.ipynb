# %%
#AFTER CONFIRMING NAMING CONVENTION DO THIS. CREATE A LIST FOR EACH KEYWORD AND GO THROUGH FILES IN FOLDER
#Remember to type in last month end for Stone file with a space before the year!
import pandas as pd

filesinfolder = [For Privacy Reasons I cannot share the names of the files.]

scotiafkeyword = ['RATESN_FCLASS']
scotiakeyword = ['RATESN ']
tempusd = ['Canada Report USD']
tempcad = ['Canada Report CAD']
scotiaprivatekeyword = ['Morningstar Pinnacle']
sunlife = ['SUNLIFE']
tdkeyword = ['APREX']
nationalbank = ['Morningstar_MonthlyPerformance']
invescokeyword = ['MR01A_MORNINGSTAR EXPORT']
iakeyword = ['Morningstar_Performance']
renaissance = ['CAMI']
agf = ['Third']
stone = ['May 31, 2020']
ratesnADVISOR = ['RATESN Advisor for']

for scotiaf in filesinfolder:
    if any(word in scotiaf for word in scotiafkeyword): 
        filepath = pd.read_excel(scotiaf,index_col=0)
        basemfid = filepath.iloc[2:,4:5]
        basemfidcheck = basemfid.iloc[0]
        basemfidcheck = basemfidcheck.iloc[0]
        returndate = filepath.iloc[2:,5:6]
        returndatecheck = returndate.iloc[0]
        returndatecheck = returndatecheck.iloc[0]
        if basemfidcheck == 'Fund Code' and returndatecheck == '1 Mth':
            print('RATESN_FLCASS File is ready to go!')
            
for scotia in filesinfolder:
    if any(word in scotia for word in scotiakeyword):
        filepathscotia = pd.read_excel(scotia,index_col=0)
        b = filepathscotia.iloc[2:,21:22]
        b = b.iloc[0]
        b = b.iloc[0]
        r = filepathscotia.iloc[2:,2:3]
        r = r.iloc[0]
        r = r.iloc[0]
        if b == 'MF ID #' and r == '1 Mth':
            print('RATESN File is ready to go!')
            
for canreportusd in filesinfolder:
    if any(word in canreportusd for word in tempusd):
        filepathcanreportusd = pd.read_excel(canreportusd,index_col=0)
        tempusddateusd = filepathcanreportusd.iloc[3:,5:6]
        tempusddateusd = tempusddateusd.iloc[0]
        tempusddateusd = tempusddateusd.iloc[0]
        if tempusddateusd == '1 Mth':
            print('Canada Report USD file is ready to go!')
            
for canreportcad in filesinfolder:
    if any(word in canreportcad for word in tempcad):
        filepathcanreportcad = pd.read_excel(canreportcad,index_col=0)
        tempusddatecad = filepathcanreportcad.iloc[3:,5:6]
        tempusddatecad = tempusddatecad.iloc[0]
        tempusddatecad = tempusddatecad.iloc[0]
        if tempusddatecad == '1 Mth':
            print('Canada Report CAD file is ready to go!')
            
for scotiaprivate in filesinfolder:
    if any(word in scotiaprivate for word in scotiaprivatekeyword):
        filepathscotiaprivate = pd.read_excel(scotiaprivate)
        pinmfid = filepathscotiaprivate.iloc[2:,0:1]
        pinmfid = pinmfid.iloc[0]
        pinmfid = pinmfid.iloc[0]
        pindate = filepathscotiaprivate.iloc[2:,11:12]
        pindate = pindate.iloc[0]
        pindate = pindate.iloc[0]
        if pinmfid == 'MFIDs' and pindate == '1M':
            print('Pinnacale File is Ready to Go')
            
for sunlifefile in filesinfolder:
    if any(word in sunlifefile for word in sunlife):
        sunlifedata = pd.read_excel(sunlifefile)
        sunid = sunlifedata.iloc[4:,2:3]
        sun = sunid.iloc[0]
        suncode = sun.iloc[0]
        sundateone = sunlifedata.iloc[4:,6:7]
        sundate = sundateone.iloc[0]
        sundate = sundate.iloc[0]
        if suncode == 'Morningstar Codes' and sundate == 'Total Ret \n1 Mo \n(Mo-End)':
            print('Sun Life file is ready to go!')
            
for td in filesinfolder:
    if any(word in td for word in tdkeyword):
        tdfile = pd.read_excel(td)
        code = tdfile.iloc[6:,0:1]
        tdcode = code.iloc[0]
        tdcode = tdcode.iloc[0]
        date = tdfile.iloc[5:,6:7]
        tddate = date.iloc[0]
        tddate = tddate.iloc[0]
        if tdcode == 'MORNINGSTAR' and tddate == '1 Mo.':
            print('TD File is ready to go!')

for nb in filesinfolder:
    if any(word in nb for word in nationalbank):
        nbfile = pd.read_excel(nb,header = None)    
        ncode = nbfile.iloc[:,2:3]
        ncode = ncode.iloc[0]
        ncode = ncode.iloc[0]
        ndate = nbfile.iloc[:,25:26]
        ndate = ndate.iloc[0]
        ndate = ndate.iloc[0]    
        if ncode == "Morningstar Code" and ndate == 'Total 1Mo Return':
            print('National Bank File is Ready to go!')
            
for invesco in filesinfolder:
    if any(word in invesco for word in invescokeyword):
        invescofile = pd.read_excel(invesco,header=None)
        icode = invescofile.iloc[:,2:3]
        icode = icode.iloc[0]
        icode = icode.iloc[0]
        idate = invescofile.iloc[:,6:7]
        idate = idate.iloc[0]
        idate = idate.iloc[0]
        if icode == 'Ext Fund Number' and idate == '1 Month':
            print('Invesco File is good to go!')
            
for ia in filesinfolder:
    if any(word in ia for word in iakeyword):
        iafile = pd.read_excel(ia,header=None)
        iacode = iafile.iloc[2:,0:1]
        iacode = iacode.iloc[0]
        iacode = iacode.iloc[0]
        iadate = iafile.iloc[2:,2:3]
        iadate = iadate.iloc[0]
        iadate = iadate.iloc[0]
        if iacode == 'Morningstar Security ID' and iadate == 'Total Ret \n1 Mo \n(Mo-End)':
            print('IA File is good to go!')
            
for rn in filesinfolder:
    if any(word in rn for word in renaissance):
        rnfile = pd.read_excel(rn,header=None)
        rncode = rnfile.iloc[9:,29:30]
        rncode = rncode.iloc[0]
        rncode = rncode.iloc[0]
        rndate = rnfile.iloc[8:,7:8]
        rndate = rndate.iloc[0]
        rndate = rndate.iloc[0]
        if rncode == 'Fund & Class' and rndate == '1 Month':
            print('Renaissance File is good to go!')
            
for af in filesinfolder:
    if any(word in af for word in agf):
        agffile = pd.read_excel(af,header=None)
        agfcode = agffile.iloc[2:3,0:1]
        agfcode = agfcode.iloc[0]
        agfcode = agfcode.iloc[0]
        agfdate = agffile.iloc[2:3,8:9]
        agfdate = agfdate.iloc[0]
        agfdate = agfdate.iloc[0]
        if agfcode == 'EntityID' and agfdate == 'Net Return 1 Month':
            print('AGF File is good to go!')
            
for st in filesinfolder:
    if any(word in st for word in stone):
        stonefile = pd.read_excel(st,header=None)
        stonecode = stonefile.iloc[5:6,2:3]
        stonecode = stonecode.iloc[0]
        stonecode = stonecode.iloc[0]
        stonedate = stonefile.iloc[5:6,6:7]
        stonedate = stonedate.iloc[0]
        stonedate = stonedate.iloc[0]
        if stonedate == 'Total Ret \n1 Mo \n(Mo-End)' and stonecode == 'Morningstar Codes':
            print('Stone File is good to go!')
            
for rnadv in filesinfolder:
    if any(word in rnadv for word in ratesnADVISOR):
        rnadvfile = pd.read_excel(rnadv,header=None)
        rnadvcode = rnadvfile.iloc[3:4,3:4]
        rnadvcode = rnadvcode.iloc[0]
        rnadvcode = rnadvcode.iloc[0]
        rnadvdate = rnadvfile.iloc[3:4,4:5]
        rnadvdate = rnadvdate.iloc[0]
        rnadvdate = rnadvdate.iloc[0]
        if rnadvdate == '1 Mth' and rnadvcode == 'Fund Code':
            print('Rates Advisor File is good to go!')
